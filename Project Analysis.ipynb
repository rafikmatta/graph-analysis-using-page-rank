# %%
import networkx as nx
from networkx.algorithms import approximation,community
G = nx.read_edgelist('edge_list.csv',delimiter=',',data=(('type',str),))

# %%
node_dict = dict(G.adj)

# %%
list(nx.algorithms.community.label_propagation_communities(G))
# Out:
# [{'hilemangroup.com', 'solomononline.com'},
#  {'012mobile.co.il',
#   'bankhapoalim.co',
#   'bezeq.co.il',
#   'cellcom.com',
#   'clalit.co.il',
#   'ectel.int',
#   'eds.com',
#   'flashnetworks.com',
#   'fxbrokersreviews.com',
#   'idf.org',
#   'iec.ch',
#   'iscar.com',
#   'jacada.com',
#   'meuhedet.co.il',
#   'midlink.co.il',
#   'mirs.cl',
#   'orbotech.com',
#   'pelephone.co.il',
#   'policemutual.co.uk',
#   'rafael.co.il',
#   'retalix.com',
#   'shufersal.co.il',
#   'tase.co.il'},
#  {'ch2mhill.com',
#   'cloversolutions.us',
#   'cticompanies.com',
#   'dixonenvironmental.com',
#   'e2managetech.com',
#   'ecubed.us.com',
#   'enviance.com',
#   'hucoinc.com',
#   'sitehawk.com',
#   'stanleyconsultants.com',
#   'trinityconsultants.com',
#   'westonsolutions.com'},
#  {'babilon-m.tj',
#   'banglalink.com.bd',
#   'beeline.kz',
#   'dialog.lk',
#   'digi.com.my',
#   'digicelgroup.com',
#   'dtac.co.th',
#   'g-mobile.mn',
#   'grameenphone.com',
#   'iam.ma',
# ...

# %%
len(G)
# Out:
# 51104
